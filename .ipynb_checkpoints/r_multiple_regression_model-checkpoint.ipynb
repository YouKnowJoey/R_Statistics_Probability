# %% [markdown]
# # Multiple Regression Model

# %%
# Load the mtcars dataset
data(mtcars)

# Calculate correlation matrix
cor_matrix <- cor(mtcars)
print(cor_matrix)
# Out:
#             mpg        cyl       disp         hp        drat         wt
# mpg   1.0000000 -0.8521620 -0.8475514 -0.7761684  0.68117191 -0.8676594
# cyl  -0.8521620  1.0000000  0.9020329  0.8324475 -0.69993811  0.7824958
# disp -0.8475514  0.9020329  1.0000000  0.7909486 -0.71021393  0.8879799
# hp   -0.7761684  0.8324475  0.7909486  1.0000000 -0.44875912  0.6587479
# drat  0.6811719 -0.6999381 -0.7102139 -0.4487591  1.00000000 -0.7124406
# wt   -0.8676594  0.7824958  0.8879799  0.6587479 -0.71244065  1.0000000
# qsec  0.4186840 -0.5912421 -0.4336979 -0.7082234  0.09120476 -0.1747159
# vs    0.6640389 -0.8108118 -0.7104159 -0.7230967  0.44027846 -0.5549157
# am    0.5998324 -0.5226070 -0.5912270 -0.2432043  0.71271113 -0.6924953
# gear  0.4802848 -0.4926866 -0.5555692 -0.1257043  0.69961013 -0.5832870
# carb -0.5509251  0.5269883  0.3949769  0.7498125 -0.09078980  0.4276059
#             qsec         vs          am       gear        carb
# mpg   0.41868403  0.6640389  0.59983243  0.4802848 -0.55092507
# cyl  -0.59124207 -0.8108118 -0.52260705 -0.4926866  0.52698829
# disp -0.43369788 -0.7104159 -0.59122704 -0.5555692  0.39497686
# hp   -0.70822339 -0.7230967 -0.24320426 -0.1257043  0.74981247
# drat  0.09120476  0.4402785  0.71271113  0.6996101 -0.09078980
# wt   -0.17471588 -0.5549157 -0.69249526 -0.5832870  0.42760594
# qsec  1.00000000  0.7445354 -0.22986086 -0.2126822 -0.65624923
# vs    0.74453544  1.0000000  0.16834512  0.2060233 -0.56960714
# am   -0.22986086  0.1683451  1.00000000  0.7940588  0.05753435
# gear -0.21268223  0.2060233  0.79405876  1.0000000  0.27407284
# carb -0.65624923 -0.5696071  0.05753435  0.2740728  1.00000000

# %%
# Fit the multiple regression model
model <- lm(mpg ~ cyl + disp + hp + wt + qsec, data = mtcars)
anova(model)
# Summary of the model
summary(model)
# Out:
#           Df Sum Sq     Mean Sq    F value     Pr(>F)
# cyl        1 817.712952 817.712952 126.0366558 1.807934e-11
# disp       1  37.593953  37.593953   5.7944736 2.347287e-02
# hp         1   9.370929   9.370929   1.4443706 2.402661e-01
# wt         1  90.924988  90.924988  14.0145529 9.091192e-04
# qsec       1   1.759020   1.759020   0.2711233 6.069856e-01
# Residuals 26 168.685345   6.487898          NA           NA
# Call:
# lm(formula = mpg ~ cyl + disp + hp + wt + qsec, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.3117 -1.3483 -0.4352  1.2603  5.6094
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 35.87361    9.91809   3.617  0.00126 **
# cyl         -1.15608    0.71525  -1.616  0.11809
# disp         0.01195    0.01191   1.004  0.32484
# hp          -0.01584    0.01527  -1.037  0.30908
# wt          -4.22527    1.25239  -3.374  0.00233 **
# qsec         0.25382    0.48746   0.521  0.60699
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.547 on 26 degrees of freedom
# Multiple R-squared:  0.8502,	Adjusted R-squared:  0.8214
# F-statistic: 29.51 on 5 and 26 DF,  p-value: 6.182e-10

# %%
# Residuals vs Fitted Plot
plot(fitted(model), residuals(model),
     xlab = "Fitted Values", ylab = "Residuals",
     main = "Residuals vs Fitted Values")
abline(h = 0, col = "red")
# Out:
# Plot with title "Residuals vs Fitted Values"

# %%
# Standardized Residuals
sresid <- rstandard(model)

# Histogram of Standardized Residuals
hist(sresid, breaks = 10, main = "Histogram of Standardized Residuals",
     xlab = "Standardized Residuals", col = "lightblue", border = "black")
# Out:
# Plot with title "Histogram of Standardized Residuals"

# %%
plot(model, which = 1)
# Out:
# Plot with title ""

# %%
plot(model, which = 2)
# Out:
# Plot with title ""
